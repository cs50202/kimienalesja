# %% [markdown]
# # Koelen van metalen buizen
# <!-- vervang bovenstaande titel -->

# %% [markdown]
# # Introductie
#
# In het boek wordt in hoofdstuk 2 geschreven over warmtetransport. Dat kan op drie manieren plaatsvinden. Het is niet eenvoudig om deze drie verschillende vormen uit elkaar te houden. In het vak 'Fysische Transportverschijnselen', dat in het tweede jaar wordt gegeven, zal je zien dat de natuurkunde achter deze verschillende vormen van warmtetransport ook best ingewikkeld is.
#
# ```{exercise}
# Welke vormen van warmtetransport bestaan er?
# straling, geleiding en convectie
# ```
#
# In deze proef proberen we een inschatting te maken van de ordegrootte van de verschillende vormen van warmtetransport bij de koeling van een metalen buis aan lucht.

# %% [markdown]
# # Theorie

# %% [markdown]
# Volgens [Newton's wet van afkoeling](https://nl.wikipedia.org/wiki/Afkoelingswet_van_Newton) is de snelheid waarmee een voorwerp afkoelt evenredig met het verschil in de temperatuur van het voorwerp ($T$) en de omgeving ($T_0$). We kunnen dit schrijven als:
#
# $$
#     \dot{Q} = -hA(T(t) - T_0),
# $$
#
# waarin
#
# - $\dot{Q}$ de warmtestroom in $\mathrm{W}$,
# - $A$ het oppervlak waardoor koeling optreedt in $\mathrm{m}^2$,
# - $h$ de warmteoverdrachtscoëfficiënt in $\mathrm{W/(m^2 K)}$.
#
# Dit levert de differentiaalvergelijking
#
# $$
#     C\dot{T} = -hA(T(t) - T_0),
# $$
#
# met $C$ de warmtecapaciteit in $\mathrm{J/kg}$. Herschrijven met $\tau = \frac{C}{hA}$ levert:
#
# $$
#     -\tau\dot{T} = T(t) - T_0,
# $$ (eq:dv1)
#
# met als oplossing:
#
# $$
#     T(t) - T_0 = (T(0) - T_0)\text{e}^{-t/\tau}.
# $$ (eq:dv1_opl)
#
# We kunnen hieruit dus concluderen dat $\tau$ de karakteristieke tijdsduur is waarin de temperatuur van de buis een factor $\text{e}$ verlaagd ten opzichte van de omgevingstemperatuur.
#
# ```{exercise} Oplossing DV controleren
# :label: ex-dvopl
# Controleer bovenstaande door vergelijking [](#eq:dv1_opl) te substitueren in [](#eq:dv1).
# ```

# %% [markdown]
# ````{solution} ex-dvopl
# #your code/answer
# ````
# $$
#     T(t) = T_0 + (T(0) - T_0)\text{e}^{-t/\tau}.
# $$
#
# aan beide kanten differentieren
# $$
#     \dot{T} = -\frac{1}{\tau} (T(0) - T_0)e^{-t/\tau}
# $$
#
# als je dan aan beide kanten vermenigvuldigt met -$\tau$ krijg je
#
# $$
#     -\tau\dot{T} = T(t) - T_0,
# $$

# %% [markdown]
# We zijn hier voor het gemak uitgegaan van een $h$ die onafhankelijk is van de temperatuur. We weten echter dat warmtetransport door straling niet lineair gaat, maar als
#
# $$
#     \dot{Q}_s = \epsilon \sigma A (T^4 - T_0^4).
# $$
#
# Voor kleine temperatuurverschillen ($\Delta T = T - T_0$) is dit te vereenvoudigen tot
#
# $$
#     \dot{Q}_s = \epsilon \sigma A ((T_0+\Delta T)^4 - T_0^4) \approx \epsilon \sigma 4A T_0^3 \Delta T.
# $$
#
# Zolang $\Delta T$ dus relatief klein is ten opzichte van $T_0$, kunnen we $h$ dus inderdaad als een constante beschouwen.
#
# ```{exercise} Uitwerken
# :label: ex_uitw
#
# Laat zien dat bovenstaande geldt door eerst $(T_0+\Delta T)^4$ uit te schrijven, te substitueren en dan te bedenken dat $\Delta T$ klein is en $\Delta T^2$ dus nog kleiner.
# ```
#
# ```{solution} ex_uitw
# #your code/answer
#
# helemaal uitgeschreven:
#
# ```
# $
#     (T_0 + \Delta T)^4 = T_0^4 + 4T_0^3 \Delta T + 6T_0^2 \Delta T^2 + 4T_0 \Delta T^3 + \Delta T^4
# $
#
# dus
#
# $
#     (T_0 + \Delta T)^4 - T_0^4 = 4T_0^3 \Delta T + 6T_0^2 \Delta T^2 + 4T_0 \Delta T^3 + \Delta T^4
# $
#
# $
#     \Delta T$ is al klein dus hogere machten zijn dan nog kleiner dan de term met $\Delta T$, daardoor kunnen de hogere termen verwaarloosd worden
# $
#
# ```{exercise}
# :label: ex_fout
# Hoe groot is de fout in het warmtetransport door straling die we maken voor het temperatuurbereik waarin we deze proef uitvoeren?
# ```
#
# ```{solution} ex_fout
# #your code/answer
# ```
# De fout door de linearisatie is gegeven door het verschil in de exacte en gelineariseerde waarde, delen door de exacte waarde
#
# Dus voor de fout:
# $
#     \frac{6T_0^2 \Delta T^2 + 4T_0 \Delta T^3 + \Delta T^4}{T_0^4 + 4T_0^3 \Delta T + 6T_0^2 \Delta T^2 + 4T_0 \Delta T^3 + \Delta T^4}
# $
#
# invullen van $T_0 \approx 50 + 273.15 K$ en $\Delta T \approx 20 + 273.15 K$ geeft 0.65 als fout.

# %% [markdown]
# # Methode en materialen
#
# ## Ontwerp
#
# ## Materialen
#
# - standaard met twee thermisch geïsoleerde grijparmen
# - metalen buis me bijpassende dop
# - thermometer (infrarood of thermokoppel)
# - knijper voor bevestigen thermokoppel op buis
# - warm water tussen 60 en 80 graden Celsius
# - (evt) schuifmaat voor bepalen dimensies buis
#
# ## Procedure
#
# Stop de buis in warm water en laat deze gedurende een paar minuten zitten om thermisch evenwicht te bereiken. Beantwoord ondertussen de volgende vragen met behulp van de tabel:
#
# | Materiaal | $\rho$ in $\text{kg/m}^3$ | $C$ in $\text{J} / \text{(kg K)}$ |
# | --------- | --------- | ------------------ |
# | messing   | 8,73E3    | 3,8E2 |
# | aluminium | 2,7E3     | 8,8E2 |
# | staal     | 7,9E3     | 4,7E2 |
#
#
# ```{exercise} constanten
# :label: ex_const
# Wat is het buitenoppervlak van de buis?
# Wat is de warmtecapaciteit van de buis?
# Wat is de omgevingstemperatuur?
#
# zie de onderstaande code voor het antwoord op deze vraag.
# ```
#
#
#
# Pak de buis op met thermisch isolerende handschoenen (of direct met de geïsoleerde grijparm) en plaats deze in de grijparm met isolatieschoentjes.
# Positioneer de thermometer voor optimale temperatuurlezing.
# Meet als functie van tijd hoe lichaam koelt.
# Wacht voldoende lang zodat je de karakteristieke tijd $\tau$ voor de afkoeling kan bepalen.
#
# ```{exercise} Configuratie
# :label: ex_conf
# Maakt het uit in welke richting je de (cilindrische) as van de buis legt? En waarom zit er een dop bij de buis?
# ```
#
# ```{solution} ex_conf
# Ja, het maakt uit in welke richting je de buis legt. Bij een andere orientatie moet de afkoelende lucht zich op een andere manier bewegen. De convectie is dus anders, waardoor de afkoeling anders zal verlopen.
#
# Een dop heeft ook een effect op het warmteverlies via convectie. Warme lucht binnenin de buis kan dan alleen van een richting ontsnappen, wat naar verwachting een grotere afkoeltijd zal veroorzaken.
#
# Beide aanpassingen aan de opstelling zullen dus zorgen voor een andere berekening van $\tau$.
# ```
#
# Doe dit voor twee of drie configuraties:
#
# 1. De buis met de as in verticale richting en afgesloten met dop.
# 2. De buis met de as in verticale richting *zonder* dop.
# 3. (alleen bij voldoende tijd) De buis met de as in horizontale richting en afgesloten met dop.
#
# ```{warning} Veiligheid
# Zorg ervoor dat je de buis niet aanraakt terwijl deze warm is. De metalen buis geleidt warmte. Zelfs een temperatuur van 60 graden celsius is daarom al onaangenaam hoog. Hou de pan met het warme water ook op een veilige plek zodat deze niet kan omkiepen en het warme water over de grond opspat.
# ```
#
#
# ## Data analyse
#
# - Bepaal de karakteristieke tijd $\tau$ waarin de temperatuur van buis afneemt. Deze kan verschillend zijn voor de drie bovenstaande configuraties.
# - Bereken hieruit de warmteoverdrachtscoëfficiënt.
# - Vergelijk je resultaten met je groepsgenoten die een vergelijkbare buis hebben gemeten (dit kan klassikaal).
# - Welk deel van de warmteoverdrachtscoëfficiënt verwacht je dat gegeven is door de geleiding, straling en convectie? Onderbouw je redenering.

# %% [markdown]
# # Resultaten

# %%
# Hier de data en de analyse

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

dikte = 0.0026
breed = 0.0502
leng = 0.10092

def oppervlak(d, b, l):
    buitenopp = b*np.pi*l
    binnenopp = (b-(2*d))*np.pi*l
    rand = 2*(((b/2)**2*np.pi)-((b-(2*d)/2)**2)*np.pi)
    A = buitenopp + binnenopp + rand
    return A


def exp_func(t, A, tau, T_omg):
    # A is verschiltemperatuur met omgeving aan start
    # tau is de karakteristieke tijd voor de koeling
    # T_omg is de omgevingstemperatuur
    return (A * np.exp(-t/tau) + T_omg)  

buitenoppervlak = oppervlak(dikte, breed, leng) # bepaal zelf in m^2
warmtecapaciteit = 8.8e2 # We hebben een aluminium buis, warmtecapaciteit in kg K
print(f"uitwerking van opdracht 5: het berekende buitenoppervlak is {buitenoppervlak:.2g} m^2, de warmtecapaciteit is {warmtecapaciteit:.2g} kg K en we schatten de omgevingstemperatuur op 23 graden celcius")

# We meten met een tijdsinterval van 5 seconden
times = np.arange(0, 651, 5)

# Eerste run van de proef, zonder dop
temps = np.array([49.9, 49.5, 49.1, 48.8, 48.5, 48.1, 47.8, 47.4, 47.1, 46.8, 46.4, 46.1, 45.8, 45.5, 45.2, 45.0, 44.9, 44.5, 44.3, 44.1, 43.8, 43.5, 43.2, 43.0, 42.7, 42.5, 
                  42.2, 42.0, 41.9, 41.7, 41.4, 41.1, 41.1, 40.9, 40.7, 40.5, 40.3, 40.0, 39.9, 39.7, 39.5, 39.3, 39.1, 39.0, 38.7, 38.5, 38.4, 38.2, 38.1, 38.0, 37.8, 37.6, 37.5, 37.2, 37.1,
                  37.0, 36.9, 36.7, 36.6, 36.4, 36.3, 36.3, 36.1, 36.0, 35.9, 35.7, 35.6, 35.5, 35.3, 35.2, 35.1, 35.0, 34.9, 34.8, 34.7, 34.7, 34.6, 34.5, 34.3, 34.3, 34.2, 34.1, 34.0, 33.9,
                  33.8, 33.7, 33.6, 33.5, 33.4, 33.3, 33.2, 33.2, 33.2, 33.1, 33.0, 33.0, 32.8, 32.7, 32.7, 32.6, 32.5, 32.4, 32.3, 32.2, 32.2, 32.2, 32.1, 32.0, 32.0, 32.0, 32.0, 31.8, 31.7,
                  31.6, 31.6, 31.5, 31.4, 31.3, 31.3, 31.2, 31.2, 31.2, 31.1, 31.1, 31.0, 31.0, 30.9, 30.8, 30.8, 30.7, 30.7])+273.15

timesdop = np.arange(0, 651, 5)

# Tweede run van de proef, met dop
tempsdop = np.array([50.0, 49.5, 49.3, 48.9, 48.8, 48.6, 48.4, 48.3, 47.6, 47.5, 47.4, 47.0, 46.8, 46.3, 46.1, 45.8, 45.7, 45.4, 45.1, 44.9, 44.7, 44.4, 44.3, 44.3, 43.7, 43.4,
                     43.3, 43.3, 42.7, 42.4, 42.3, 42.3, 41.9, 41.7, 41.5, 41.4, 41.1, 41.0, 40.7, 40.5, 40.3, 40.2, 39.9, 39.6, 39.5, 39.3, 39.2, 38.9, 38.7, 38.8, 38.4, 38.1,
                     38.0, 37.8, 37.7, 37.7, 37.6, 37.5, 37.4, 37.3, 37.2, 37.1, 37.0, 36.8, 36.7, 36.6, 36.4, 36.4, 36.3, 36.3, 36.2, 36.2, 36.1, 35.9, 36.2, 35.6, 35.6, 35.4, 35.4, 35.3,
                     35.1, 35.0, 34.8, 34.8, 34.7, 34.6, 34.6, 34.6, 34.6, 34.6, 34.8, 34.5, 34.5, 34.3, 34.2, 34.3, 34.2, 34.0, 34.1, 33.9, 33.8, 33.9, 33.7, 33.6,33.6, 33.6, 33.5, 33.5, 
                     33.4, 33.3, 33.4, 33.2, 33.2, 33.0, 33.0, 32.8, 32.8, 32.7, 32.7, 32.7, 32.7, 32.7, 32.7, 32.5, 32.5, 32.4, 32.2, 32.5, 32.0, 32.0, 32.0])+273.15

#Fit uitvoeren
popt, pocv = curve_fit(exp_func, times, temps, p0=[0.01, 1000, 23], maxfev=5000)
poptdop, pcovdop = curve_fit(exp_func, timesdop, tempsdop, p0 = [0.01, 1000, 23], maxfev=5000)

A_exp, tau_exp, T_omg_exp = popt
Adop, taudop, Tdop = poptdop

x_fit = np.linspace(np.min(times), np.max(times), 1000)

y_fit = exp_func(x_fit, *popt)
y_fitdop = exp_func(x_fit, *poptdop)

plt.figure()
plt.xlabel('Time [s]')
plt.ylabel('Temperature [K]')

plt.plot(times, temps, 'k.', label='measurement, zonder dop')
plt.plot(timesdop, tempsdop, 'r.', label = 'measurement, met dop')
plt.plot(x_fit, y_fit, 'm--', 
         label='$T = %0.2f e^{-t/%0.4f} + %0.2f$' % (A_exp, tau_exp, T_omg_exp))
plt.plot(x_fit, y_fitdop, 'g--', 
         label='$T = %0.2f e^{-t/%0.4f} + %0.2f$' % (Adop, taudop, Tdop))

plt.legend()

plt.show()

h_exp = (warmtecapaciteit) / (tau_exp * buitenoppervlak)
h_dop = (warmtecapaciteit) / (taudop * buitenoppervlak)

#errorpropagation

u_tau_exp = np.sqrt(pocv[1,1])
u_A_exp = np.sqrt(pocv[0,0])
u_taudop = np.sqrt(pcovdop[1,1])
u_Adop = np.sqrt(pcovdop[0,0])

uhexp = np.sqrt((u_tau_exp/tau_exp)**2 + (u_A_exp/buitenoppervlak)**2)*h_exp
uhdop = np.sqrt((u_taudop/taudop)**2 + (u_Adop/buitenoppervlak)**2)*h_dop

# printen van waardes

print(f"Proef 1: zonder dop is de warmteoverdrachtscoefficient {h_exp:.4g} W/m^2 K")
print(f"Proef 1: met dop is de warmteoverdrachtscoefficient {h_dop:.4g} W/m^2 K")
# Sla figuren op met  
# 
# plt.savefig("Figuren/naam.png", dpi=450)
# Out:
# uitwerking van opdracht 5: het berekende buitenoppervlak is 0.02 m^2, de warmtecapaciteit is 8.8e+02 kg K en we schatten de omgevingstemperatuur op 23 graden celcius
# 1.6401996472772742 0.03873178820747544 3.883104640776938 0.08861976613852722
# 277.00755102969987 672.6280625897764
# Proef 1: zonder dop is de warmteoverdrachtscoefficient 142.4 W/m^2 K
# Proef 1: met dop is de warmteoverdrachtscoefficient 151.1 W/m^2 K
# 142.3617304504227

# %% [markdown]
# Het grootste gedeelte van de warmteoverdracht zal plaatsgevonden hebben als gevolg van convectie en straling. Lucht is een hele slechte geleider, dus de warmteoverdracht als gevolg van geleiding zal verwaarloosbaar klein geweest zijn. Straling is niet verwaarloosbaar, maar het grootste aandeel van de warmteoverdracht kan toegeschreven worden aan convectie, aangezien de buis veel warmer was dan de lucht, waardoor er natuurlijk sterkte convectiestromen ontstaan.

# %% [markdown]
# # Discussie en conclusie
#
# Een paar punten waarop in het vervolg verbeterd kan worden:
# - Er is geen tijd geweest om de invloed van de orientatie van de buis op de warmteoverdracht te onderzoeken, dus in een vervolg zou het interessant zijn om dat te onderzoeken
# - Door het experiment te herhalen zal de kans op random errors aanzienlijk verkleind kunnen worden
# - Bij het meten van de temperatuur zou er in een vervolg ook gelijktijdig gemeten kunnen worden op andere plekken van de buis om te kijken of die sneller/langzamer afkoelen
#
# Conclusie: wij zijn redelijk tevreden met de uitkomst van ons experiment, aangezien we de warmteoverdrachtscoefficient van de afkoelende buis met en zonder dop hebben kunnen bepalen met een goed passende fit.
